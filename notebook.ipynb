# %% [markdown]
# # Day 1

# %% [markdown]
# ## Counting words

# %%
from functions import PatternCount, FrequentWords_slow, FrequencyTable, BetterFrequentWords, GetReverse, PatternMatching

# %%
genome_file = open("chapter1.2_genome.txt", "r")
genome = str(genome_file.read())

actat_count = PatternCount(genome, "ACTAT")
print(actat_count)
# Out:
# 625

# %% [markdown]
# ## The frequent words problem

# %%
print(genome)
frequent_patterns, max_count = FrequentWords_slow(genome[0:50], 3)
print(frequent_patterns, max_count)
# Out:
# ...
# ['CAA', 'ATG', 'GAG', 'TCA', 'ATG', 'TTC', 'GAG', 'GCT', 'TTC', 'TCA', 'CAA', 'GCT', 'CGC', 'GCA', 'CGC', 'GCA'] 2

# %%
freq_map = FrequencyTable(genome, 3)
print(freq_map)
# Out:
# {'ACA': 16327, 'CAA': 26912, 'AAT': 22080, 'ATG': 18746, 'TGA': 23352, 'GAG': 13431, 'AGG': 11035, 'GGT': 15699, 'GTC': 10330, 'TCA': 23447, 'CAC': 18397, 'ACT': 16028, 'CTA': 10033, 'TAT': 14272, 'TGT': 15369, 'GTT': 19768, 'TTC': 19294, 'TCG': 15802, 'CGA': 15793, 'AGC': 20678, 'GCT': 21071, 'CTC': 14441, 'TCT': 15047, 'CTT': 21188, 'AAA': 30605, 'AAC': 20905, 'ACC': 17012, 'CCG': 13125, 'CGG': 12911, 'GGC': 17414, 'CTG': 17690, 'TGC': 21219, 'GCG': 20090, 'CGC': 20580, 'GCA': 21376, 'CAT': 19650, 'ATA': 15060, 'TAC': 12566, 'ACG': 13492, 'CAG': 17254, 'GCC': 17354, 'CCA': 21063, 'ATC': 21259, 'TCC': 11028, 'GAT': 21397, 'TAA': 17742, 'AAG': 19825, 'GTG': 16556, 'TGG': 19920, 'GGA': 10753, 'GAC': 10990, 'CGT': 13225, 'ATT': 22334, 'CCT': 11206, 'TTG': 26868, 'TTT': 31901, 'GTA': 12115, 'AGA': 14077, 'GAA': 18157, 'TTA': 17128, 'TAG': 9756, 'AGT': 14476, 'GGG': 9523, 'CCC': 10105}

# %%
freq_patterns, maximum = BetterFrequentWords(genome, 3)
print(freq_patterns, maximum)
# Out:
# ['TTT'] 31901

# %%
reverse_genome = GetReverse(genome)
print(reverse_genome)
# Out:
# ...

# %%
positions = PatternMatching(genome, "ATGATCAAG")
print(positions)
# Out:
# [116556, 149355, 151913, 152013, 152394, 186189, 194276, 200076, 224527, 307692, 479770, 610980, 653338, 679985, 768828, 878903, 985368]
